# %% [markdown]
# ### Task 1: Basic Data Profiling of a CSV File
# **Description**: Load a CSV file and generate a Pandas-Profiling report.
#
# **Steps**:
# 1. Load a CSV File: Make sure you have a CSV file (e.g., data.csv ). Load it using pandas.
# 2. Generate a Profile Report.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from ydata_profiling import ProfileReport
import ipywidgets as widgets
from IPython.display import display

# 📁 Step 1: Create Sample Dataset
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Alice'],
    'Age': [25, 30, 35, np.nan, 45, 25],
    'Salary': [50000, 60000, 70000, 80000, np.nan, 50000],
    'Department': ['HR', 'Engineering', 'Engineering', 'HR', 'Marketing', 'HR']
}
df = pd.DataFrame(data)
print("✅ Sample DataFrame created.\n")
print(df)

# 📊 Step 2: Generate Profiling Report
try:
    profile = ProfileReport(df, title="Sample Profiling Report", explorative=True)
    profile.to_file("sample_profiling_report.html")
    print("\n📄 Profiling report saved as 'sample_profiling_report.html'.")
except Exception as e:
    print(f"⚠️ Error creating profile report: {e}")

# 🔍 Step 3: Missing Value Analysis
print("\n🔍 Missing Values:")
print(df.isnull().sum())

# 📏 Step 4: Data Types
print("\n🧬 Data Types:")
print(df.dtypes)

# 🔢 Step 5: Unique Values
print("\n🔢 Unique Values per Column:")
print(df.nunique())

# 🧭 Step 6: Duplicate Rows
print("\n🧭 Duplicate Rows:")
duplicates = df[df.duplicated()]
if not duplicates.empty:
    print(duplicates)
else:
    print("No duplicates found.")

# 📈 Step 7: Visualizations

# Missing value heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title("Missing Value Heatmap")
plt.show()

# Correlation heatmap
numeric_df = df.select_dtypes(include=[np.number])
if not numeric_df.empty:
    plt.figure(figsize=(12, 10))
    mask = np.triu(np.ones_like(numeric_df.corr(), dtype=bool))
    sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', mask=mask, fmt=".2f")
    plt.title("Correlation Matrix (Upper Triangle)")
    plt.show()
else:
    print("⚠️ No numeric columns for correlation matrix.")

# 📊 Step 8: Summary Statistics
print("\n📊 Summary Statistics:")
print(df.describe(include='all'))

# 🧪 Step 9: Interactive Column Analysis
print("\n🧪 Explore Individual Columns:")
column_selector = widgets.Dropdown(options=df.columns, description='Column:')
display(column_selector)

def explore_column(column_name):
    print(f"\n📍 Analysis for Column: {column_name}")
    print("Data Type:", df[column_name].dtype)
    print("Unique Values:", df[column_name].nunique())
    print("Missing Values:", df[column_name].isnull().sum())
    print(df[column_name].value_counts(dropna=False).head(10))
    if df[column_name].dtype in ['int64', 'float64']:
        df[column_name].hist(bins=20)
        plt.title(f"Distribution of {column_name}")
        plt.xlabel(column_name)
        plt.ylabel("Frequency")
        plt.show()

widgets.interact(explore_column, column_name=column_selector)

# 📋 Step 10: Data Quality Summary
print("\n📋 Data Quality Summary:")
print(f"Total Rows: {df.shape[0]}")
print(f"Total Columns: {df.shape[1]}")
print(f"Total Missing Values: {df.isnull().sum().sum()}")
print(f"Total Duplicate Rows: {df.duplicated().sum()}")
print(f"Columns with Single Unique Value: {df.columns[df.nunique() == 1].tolist()}")

print("\n✅ Data profiling completed.")
# Out:
# ✅ Sample DataFrame created.
#
#       Name   Age   Salary   Department
# 0    Alice  25.0  50000.0           HR
# 1      Bob  30.0  60000.0  Engineering
# 2  Charlie  35.0  70000.0  Engineering
# 3    David   NaN  80000.0           HR
# 4      Eve  45.0      NaN    Marketing
# 5    Alice  25.0  50000.0           HR
# ...
# Summarize dataset:  22%|██▏       | 2/9 [00:00<00:00, 47.32it/s, Describe variable: Department]
# ⚠️ Error creating profile report: 'float' object has no attribute 'ndim'
#
# 🔍 Missing Values:
# Name          0
# Age           1
# Salary        1
# Department    0
# dtype: int64
#
# 🧬 Data Types:
# Name           object
# Age           float64
# Salary        float64
# Department     object
# dtype: object
#
# 🔢 Unique Values per Column:
# Name          5
# Age           4
# Salary        4
# Department    3
# dtype: int64
#
# 🧭 Duplicate Rows:
#     Name   Age   Salary Department
# 5  Alice  25.0  50000.0         HR
# 📊 Summary Statistics:
# ...

# %% [markdown]
# ### Task 2: Understanding Missing Values with Pandas-Profiling
#
# **Description**: Identify missing values in your dataset using pandas-profiling.
#
# **Steps**:
# 1. Generate a Profile Report to Analyze Missing Values

# %%
# Write your code from here

# %% [markdown]
# ### Task 3: Analyze Data Types Using Pandas-Profiling
# **Description**: Use Pandas-Profiling to analyze and check data types of your dataset.

# %%
# Write your code from here

# %% [markdown]
# ### Task 4: Detect Unique Values and Duplicates
# **Description**: Use Pandas-Profiling to detect unique values and duplicates in your dataset.
